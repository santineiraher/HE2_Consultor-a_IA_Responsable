# %% [markdown]
# # Pipeline clásico de regresión con Elastic Net
#
# Dataset: `quantbruce/real-estate-price-prediction` (Kaggle).
#
# Objetivos:
# - Descargar y cargar los datos.
# - Hacer una inspección rápida (tipos, faltantes, distribución).
# - Separar en train/test.
# - Construir un pipeline con preprocesamiento y `ElasticNetCV`.
# - Visualizar el error de CV y la selección de hiperparámetros.
# - Interpretar selección de variables y evaluar desempeño.
#
# > Intuición (según las presentaciones): buscamos buen desempeño fuera de muestra, controlando el overfitting con regularización (bias-variance tradeoff).

# %%
# necesitan tener instalado en sus environments todos los paquetes
# package managers: pip, conda, mamba, etc.
# pip install XX
# conda install matplotlib seaborn sklearn

import os
from pathlib import Path

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme(style="whitegrid")

from IPython.display import display

from sklearn.model_selection import train_test_split, KFold
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, StandardScaler, PolynomialFeatures
from sklearn.linear_model import ElasticNetCV, ElasticNet
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.feature_selection import SelectFromModel
from sklearn.pipeline import Pipeline

# %%
import kagglehub

path = kagglehub.dataset_download("quantbruce/real-estate-price-prediction")
print("Path to dataset files:", path)

data_dir = Path(path)
files = sorted([p for p in data_dir.rglob("*") if p.is_file()])
print("Archivos encontrados:")
for p in files:
    print(" -", p.relative_to(data_dir))
# Out:
# Path to dataset files: /Users/upar/.cache/kagglehub/datasets/quantbruce/real-estate-price-prediction/versions/1
# Archivos encontrados:
#  - Real estate.csv

# %%
csv_files = [p for p in data_dir.rglob("*.csv")]
if not csv_files:
    raise FileNotFoundError("No se encontraron CSV en el dataset.")

print("CSV encontrados:", [p.name for p in csv_files])

# Si hay varios CSV, cambia el índice manualmente.
csv_path = csv_files[0]
print("Usando:", csv_path.name)

df = pd.read_csv(csv_path)
df.head()
# Out:
# CSV encontrados: ['Real estate.csv']
# Usando: Real estate.csv
#    No  X1 transaction date  X2 house age  \
# 0   1             2012.917          32.0
# 1   2             2012.917          19.5
# 2   3             2013.583          13.3
# 3   4             2013.500          13.3
# 4   5             2012.833           5.0
#
#    X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                                84.87882                               10
# 1                               306.59470                                9
# 2                               561.98450                                5
# 3                               561.98450                                5
# 4                               390.56840                                5
#
#    X5 latitude  X6 longitude  Y house price of unit area
# 0     24.98298     121.54024                        37.9
# 1     24.98034     121.53951                        42.2
# 2     24.98746     121.54391                        47.3
# 3     24.98746     121.54391                        54.8
# 4     24.97937     121.54245                        43.1

# %%
df['Y house price of unit area'].hist()
# Out:
# <Axes: >

# %%
np.array([True, False, False]).mean()
# Out:
# 0.3333333333333333

# %%
print("Shape:", df.shape)

print("Tipos de datos (conteo):")
display(df.dtypes.value_counts())

print("Resumen estadístico (primeras filas):")
display(df.describe(include="all").transpose())

print("Faltantes (top 20):")
missing = df.isna().mean().sort_values(ascending=False)
display(missing.head(20))
# Out:
# Shape: (414, 8)
# Tipos de datos (conteo):
# float64    6
# int64      2
# Name: count, dtype: int64
# Resumen estadístico (primeras filas):
#                                         count         mean          std  \
# No                                      414.0   207.500000   119.655756
# X1 transaction date                     414.0  2013.148971     0.281967
# X2 house age                            414.0    17.712560    11.392485
# X3 distance to the nearest MRT station  414.0  1083.885689  1262.109595
# X4 number of convenience stores         414.0     4.094203     2.945562
# X5 latitude                             414.0    24.969030     0.012410
# X6 longitude                            414.0   121.533361     0.015347
# Y house price of unit area              414.0    37.980193    13.606488
#
#                                                min          25%         50%  \
# No                                         1.00000   104.250000   207.50000
# X1 transaction date                     2012.66700  2012.917000  2013.16700
# X2 house age                               0.00000     9.025000    16.10000
# X3 distance to the nearest MRT station    23.38284   289.324800   492.23130
# X4 number of convenience stores            0.00000     1.000000     4.00000
# X5 latitude                               24.93207    24.963000    24.97110
# X6 longitude                             121.47353   121.528085   121.53863
# Y house price of unit area                 7.60000    27.700000    38.45000
#
#                                                 75%         max
# No                                       310.750000   414.00000
# X1 transaction date                     2013.417000  2013.58300
# X2 house age                              28.150000    43.80000
# X3 distance to the nearest MRT station  1454.279000  6488.02100
# X4 number of convenience stores            6.000000    10.00000
# X5 latitude                               24.977455    25.01459
# X6 longitude                             121.543305   121.56627
# Y house price of unit area                46.600000   117.50000
# Faltantes (top 20):
# No                                        0.0
# X1 transaction date                       0.0
# X2 house age                              0.0
# X3 distance to the nearest MRT station    0.0
# X4 number of convenience stores           0.0
# X5 latitude                               0.0
# X6 longitude                              0.0
# Y house price of unit area                0.0
# dtype: float64

# %% [markdown]
# ## Análisis básico de correlación
#
# Una primera mirada útil es ver qué variables numéricas se relacionan más con el precio. Esto no implica causalidad; solo ayuda a construir intuición inicial.
#
# - Correlaciones altas en valor absoluto suelen ser variables más predictivas.
# - La correlación no capta relaciones no lineales.
#
# Formula de correlación de Pearson:
# $$\rho_{X,Y} = \frac{Cov(X,Y)}{\sigma_X \sigma_Y} = \frac{E[(X - \mu_X)(Y - \mu_Y)]}{\sigma_X \sigma_Y}
# $$

# %%
numeric_cols = df.select_dtypes(include=["number"]).columns
corr = df[numeric_cols].corr(method='pearson')

plt.figure(figsize=(7, 5))
sns.heatmap(corr, cmap="coolwarm", center=0, square=True, cbar_kws={"shrink": 0.8})
plt.title("Matriz de correlación (variables numéricas)")
plt.tight_layout()
plt.show()

# Intento simple de detectar el target para mostrar correlaciones
candidates = [
    c for c in numeric_cols
    if any(k in c.lower() for k in ["price", "target", "value", "precio", "valor"])
]
if candidates:
    target_for_corr = candidates[0]
    corr_target = corr[target_for_corr].sort_values(key=lambda s: s.abs(), ascending=False)
    print("Top correlaciones con el target:")
    display(corr_target.head(10))
else:
    print("No se detectó target para correlaciones. Puedes definir TARGET más abajo.")
# Out:
# Top correlaciones con el target:
# Y house price of unit area                1.000000
# X3 distance to the nearest MRT station   -0.673613
# X4 number of convenience stores           0.571005
# X5 latitude                               0.546307
# X6 longitude                              0.523287
# X2 house age                             -0.210567
# X1 transaction date                       0.087491
# No                                       -0.028587
# Name: Y house price of unit area, dtype: float64

# %%
path = "/Users/upar/Library/CloudStorage/GoogleDrive-gustavo.castillo.alvarez@gmail.com/Mon Drive/:/cool_datasets/datasaurus/generated_datasets/DatasaurusDozen.tsv"
datasaurus = pd.read_csv(path, sep='\t')

# plot `dataset=="dino"`
dino = datasaurus[datasaurus.dataset == "dino"]
def plot_fig(dataset):
    plt.figure(figsize=(5, 5))
    sns.scatterplot(data=dataset, x="x", y="y")
    plt.title(f"Dataset: {dataset['dataset'].iloc[0]}")
    plt.tight_layout()
    # plt.show()
plot_fig(dino)

# Plot `dataset=="slant_down"`
plot_fig(datasaurus[datasaurus.dataset == "slant_down"])

# %% [markdown]
# ## Interpretación de columnas (dataset de precios de vivienda)
#
# Este dataset es el clásico de **Taiwán (real estate valuation)**. Las variables significan:
#
# - `No`: ID de la transacción.
# - `X1 transaction date`: fecha de transacción (año con decimales).
# - `X2 house age`: edad de la vivienda (años).
# - `X3 distance to the nearest MRT station`: distancia a la estación MRT más cercana (metros).
# - `X4 number of convenience stores`: número de tiendas de conveniencia cercanas.
# - `X5 latitude`: latitud.
# - `X6 longitude`: longitud.
# - `Y house price of unit area`: **precio por unidad de área** (target).

# %%
column_descriptions = {
    "No": "ID de la transacción",
    "X1 transaction date": "Fecha de transacción (año con decimales)",
    "X2 house age": "Edad de la vivienda (años)",
    "X3 distance to the nearest MRT station": "Distancia a la estación MRT más cercana (metros)",
    "X4 number of convenience stores": "Número de tiendas de conveniencia cercanas",
    "X5 latitude": "Latitud",
    "X6 longitude": "Longitud",
    "Y house price of unit area": "Precio por unidad de área (target)",
}

desc_df = pd.DataFrame(
    [(c, column_descriptions.get(c, "(sin descripción)")) for c in df.columns],
    columns=["columna", "descripcion"],
)

display(desc_df)

if "Y house price of unit area" in df.columns:
    print("Sugerencia de TARGET:", "Y house price of unit area")
# Out:
#                                   columna  \
# 0                                      No
# 1                     X1 transaction date
# 2                            X2 house age
# 3  X3 distance to the nearest MRT station
# 4         X4 number of convenience stores
# 5                             X5 latitude
# 6                            X6 longitude
# 7              Y house price of unit area
#
#                                         descripcion
# 0                              ID de la transacción
# 1          Fecha de transacción (año con decimales)
# 2                        Edad de la vivienda (años)
# 3  Distancia a la estación MRT más cercana (metros)
# 4        Número de tiendas de conveniencia cercanas
# 5                                           Latitud
# 6                                          Longitud
# 7                Precio por unidad de área (target)
# Sugerencia de TARGET: Y house price of unit area

# %%
descr_lookup = {
    'No': 'ID de la transacción',
    'X1 transacion date' : 'Fecha de transacción (año con decimales)'
}

descr_lookup['No']
# Out:
# 'ID de la transacción'

# %% [markdown]
# ## Nota sobre data leakage
#
# Tal como vimos en clase, toda transformación (estandarización, one-hot, etc.) debe **ajustarse solo con training** y luego aplicarse a test. Por eso usamos un `Pipeline`: evita fugas de información y hace la evaluación más honesta.

# %%
TARGET = None  # Cambia manualmente si es necesario


def infer_target(df):
    name_candidates = [
        c for c in df.columns
        if any(k in c.lower() for k in ["price", "target", "value", "precio", "valor"])
    ]
    numeric_candidates = [c for c in name_candidates if pd.api.types.is_numeric_dtype(df[c])]
    if numeric_candidates:
        return numeric_candidates[0]
    raise ValueError(
        "No se pudo inferir la variable objetivo. Asigna TARGET manualmente."
    )


if TARGET is None:
    TARGET = infer_target(df)

print("TARGET seleccionado:", TARGET)

df = df.dropna(subset=[TARGET]).copy()

y = df[TARGET]
X = df.drop(columns=[TARGET])

# El ID de la transacción no es predictivo
if "No" in X.columns:
    X = X.drop(columns=["No"])
    print("Columna 'No' eliminada (ID de transacción)")

numeric_features = [c for c in X.columns if pd.api.types.is_numeric_dtype(X[c])]
categorical_features = [c for c in X.columns if c not in numeric_features]

print("Nº features numéricas:", len(numeric_features))
print("Nº features categóricas:", len(categorical_features))
# Out:
# TARGET seleccionado: Y house price of unit area
# Columna 'No' eliminada (ID de transacción)
# Nº features numéricas: 6
# Nº features categóricas: 0

# %%
X.shape, y.shape
# Out:
# ((414, 6), (414,))

# %% [markdown]
# ## Pipeline paso a paso (versión didáctica)
#
# 1. **Train/Test split**: medimos desempeño en datos no vistos.
# 2. **Preprocesamiento**: estandarizamos numéricas y hacemos one-hot en categóricas.
# 3. **Modelo**: `ElasticNetCV` elige la mejor regularización por validación cruzada.
# 4. **Evaluación**: comparamos RMSE y $R^2$ en train vs. test.

# %%
# 1. Split dataset
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, random_state=1999
)

print("Train size:", X_train.shape[0])
print("Test size:", X_test.shape[0])

# Fijar preprocesamiento
preprocess = ColumnTransformer(
    transformers=[
        ("num", StandardScaler(), numeric_features),
        ("cat", OneHotEncoder(handle_unknown="ignore"), categorical_features),
    ],
    remainder="drop",
)

# Construir el modelo
# Grilla de búsqueda de hiperparámetros
alphas = np.logspace(-4, 2, 30)
l1_ratios = [0.1, 0.5, 0.9, 1.0] # mezcla

cv = KFold(n_splits=5, shuffle=True, random_state=42)
print(cv)

elastic_cv = ElasticNetCV(
    l1_ratio=l1_ratios,
    alphas=alphas,
    cv=cv,
    max_iter=20000,
    n_jobs=-1,
)

pipe = Pipeline(
    steps=[
        ("preprocess", preprocess),
        ("model", elastic_cv),
    ]
)

type(pipe)
pipe
# Out:
# Train size: 331
# Test size: 83
# KFold(n_splits=5, random_state=42, shuffle=True)
# Pipeline(steps=[('preprocess',
#                  ColumnTransformer(transformers=[('num', StandardScaler(),
#                                                   ['X1 transaction date',
#                                                    'X2 house age',
#                                                    'X3 distance to the nearest '
#                                                    'MRT station',
#                                                    'X4 number of convenience '
#                                                    'stores',
#                                                    'X5 latitude',
#                                                    'X6 longitude']),
#                                                  ('cat',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   [])])),
#                 ('model',
#                  ElasticNetCV(alphas=array([1.00000000e-04, 1.61026203e-04, 2.59294380e-0...
#        3.03919538e-02, 4.89390092e-02, 7.88046282e-02, 1.26896100e-01,
#        2.04335972e-01, 3.29034456e-01, 5.29831691e-01, 8.53167852e-01,
#        1.37382380e+00, 2.21221629e+00, 3.56224789e+00, 5.73615251e+00,
#        9.23670857e+00, 1.48735211e+01, 2.39502662e+01, 3.85662042e+01,
#        6.21016942e+01, 1.00000000e+02]),
#                               cv=KFold(n_splits=5, random_state=42, shuffle=True),
#                               l1_ratio=[0.1, 0.5, 0.9, 1.0], max_iter=20000,
#                               n_jobs=-1))])

# %% [markdown]
# ## Extensión opcional: polinomios (para no-linealidad)
#
# Si crees que la relación no es lineal, puedes incluir términos polinomiales en las **variables numéricas**. Esto aumenta la complejidad (más parámetros), por eso es clave la regularización y la validación cruzada.
#
# Abajo un ejemplo con grado 2.

# %%
# Nota: este bloque es opcional. Cambia degree=2 a 3 si quieres probar.
poly_preprocess = ColumnTransformer(
    transformers=[
        (
            "num",
            Pipeline(
                steps=[
                    ("poly", PolynomialFeatures(degree=2, include_bias=False)),
                    ("scaler", StandardScaler()),
                ]
            ),
            numeric_features,
        ),
        ("cat", OneHotEncoder(handle_unknown="ignore"), categorical_features),
    ],
    remainder="drop",
)

poly_model = ElasticNetCV(
    l1_ratio=l1_ratios,
    alphas=alphas,
    cv=cv,
    max_iter=20000,
    n_jobs=-1,
)

poly_pipe = Pipeline(
    steps=[
        ("preprocess", poly_preprocess),
        ("model", poly_model),
    ]
)
display(poly_pipe)
poly_pipe.fit(X_train, y_train) #entrenamos!!
poly_test_pred = poly_pipe.predict(X_test)
# Out:
# Pipeline(steps=[('preprocess',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('poly',
#                                                                    PolynomialFeatures(include_bias=False)),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['X1 transaction date',
#                                                    'X2 house age',
#                                                    'X3 distance to the nearest '
#                                                    'MRT station',
#                                                    'X4 number of convenience '
#                                                    'stores',
#                                                    'X5 latitude',
#                                                    'X6 longitude']),
#                                                  ('cat',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   [])])),
#                 ('...
#        3.03919538e-02, 4.89390092e-02, 7.88046282e-02, 1.26896100e-01,
#        2.04335972e-01, 3.29034456e-01, 5.29831691e-01, 8.53167852e-01,
#        1.37382380e+00, 2.21221629e+00, 3.56224789e+00, 5.73615251e+00,
#        9.23670857e+00, 1.48735211e+01, 2.39502662e+01, 3.85662042e+01,
#        6.21016942e+01, 1.00000000e+02]),
#                               cv=KFold(n_splits=5, random_state=42, shuffle=True),
#                               l1_ratio=[0.1, 0.5, 0.9, 1.0], max_iter=20000,
#                               n_jobs=-1))])
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.743e+01, tolerance: 4.978e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.831e+01, tolerance: 5.057e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.743e+01, tolerance: 4.978e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.430e+02, tolerance: 4.730e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.873e+01, tolerance: 4.505e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.502e+01, tolerance: 4.978e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.299e+02, tolerance: 5.111e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.050e+02, tolerance: 5.111e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.306e+01, tolerance: 4.505e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.756e+02, tolerance: 4.978e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.663e+02, tolerance: 4.730e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.877e+02, tolerance: 5.057e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.233e+02, tolerance: 4.978e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.586e+02, tolerance: 5.111e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.361e+02, tolerance: 5.111e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.708e+02, tolerance: 4.505e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.863e+01, tolerance: 4.505e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.080e+03, tolerance: 4.978e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.558e+03, tolerance: 5.057e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.954e+03, tolerance: 4.730e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.191e+03, tolerance: 5.111e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.682e+02, tolerance: 4.505e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.577e+02, tolerance: 4.978e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.681e+03, tolerance: 5.111e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.338e+03, tolerance: 4.730e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.229e+03, tolerance: 5.057e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.009e+03, tolerance: 4.505e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.006e+03, tolerance: 5.111e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.160e+03, tolerance: 4.505e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.704e+03, tolerance: 4.978e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.581e+00, tolerance: 4.730e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.874e+00, tolerance: 5.057e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.233e+02, tolerance: 4.730e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.060e+00, tolerance: 5.057e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.436e+00, tolerance: 4.505e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.224e+00, tolerance: 4.730e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.341e+01, tolerance: 4.505e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.612e+00, tolerance: 4.978e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.237e+01, tolerance: 5.057e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.028e+01, tolerance: 5.111e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.374e+01, tolerance: 4.505e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.166e+01, tolerance: 5.057e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.126e+03, tolerance: 4.730e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.182e+01, tolerance: 4.730e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.389e+02, tolerance: 4.505e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.618e+01, tolerance: 4.505e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.398e+02, tolerance: 5.057e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.547e+01, tolerance: 4.978e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.262e+02, tolerance: 5.057e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.348e+02, tolerance: 5.111e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.587e+03, tolerance: 4.730e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.298e+02, tolerance: 4.730e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.849e+03, tolerance: 4.505e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.436e+02, tolerance: 4.505e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.038e+02, tolerance: 5.111e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.724e+02, tolerance: 4.978e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.827e+01, tolerance: 4.730e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.475e+02, tolerance: 5.057e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.115e+03, tolerance: 5.057e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.388e+03, tolerance: 4.505e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.215e+02, tolerance: 5.111e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.648e+02, tolerance: 4.730e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.602e+02, tolerance: 4.978e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.195e+02, tolerance: 5.057e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.877e+02, tolerance: 5.111e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.172e+03, tolerance: 4.730e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.060e+01, tolerance: 4.730e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.306e+03, tolerance: 4.978e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.989e+03, tolerance: 5.057e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.856e+00, tolerance: 4.978e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.188e+02, tolerance: 4.730e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.594e+01, tolerance: 5.111e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.383e+01, tolerance: 5.057e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.472e+00, tolerance: 4.978e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.399e+01, tolerance: 4.730e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.640e+02, tolerance: 5.111e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.399e+02, tolerance: 5.057e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.526e+01, tolerance: 4.978e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.089e+03, tolerance: 4.730e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.187e+03, tolerance: 5.111e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.002e+02, tolerance: 5.057e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.515e+02, tolerance: 4.978e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.335e+03, tolerance: 4.730e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.730e+03, tolerance: 5.057e+00
#   model = cd_fast.enet_coordinate_descent_gram(

# %%
pipe
# Out:
# Pipeline(steps=[('preprocess',
#                  ColumnTransformer(transformers=[('num', StandardScaler(),
#                                                   ['X1 transaction date',
#                                                    'X2 house age',
#                                                    'X3 distance to the nearest '
#                                                    'MRT station',
#                                                    'X4 number of convenience '
#                                                    'stores',
#                                                    'X5 latitude',
#                                                    'X6 longitude']),
#                                                  ('cat',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   [])])),
#                 ('model',
#                  ElasticNetCV(alphas=array([1.00000000e-04, 1.61026203e-04, 2.59294380e-0...
#        3.03919538e-02, 4.89390092e-02, 7.88046282e-02, 1.26896100e-01,
#        2.04335972e-01, 3.29034456e-01, 5.29831691e-01, 8.53167852e-01,
#        1.37382380e+00, 2.21221629e+00, 3.56224789e+00, 5.73615251e+00,
#        9.23670857e+00, 1.48735211e+01, 2.39502662e+01, 3.85662042e+01,
#        6.21016942e+01, 1.00000000e+02]),
#                               cv=KFold(n_splits=5, random_state=42, shuffle=True),
#                               l1_ratio=[0.1, 0.5, 0.9, 1.0], max_iter=20000,
#                               n_jobs=-1))])

# %%
pipe.named_steps['model']
# Out:
# ElasticNetCV(alphas=array([1.00000000e-04, 1.61026203e-04, 2.59294380e-04, 4.17531894e-04,
#        6.72335754e-04, 1.08263673e-03, 1.74332882e-03, 2.80721620e-03,
#        4.52035366e-03, 7.27895384e-03, 1.17210230e-02, 1.88739182e-02,
#        3.03919538e-02, 4.89390092e-02, 7.88046282e-02, 1.26896100e-01,
#        2.04335972e-01, 3.29034456e-01, 5.29831691e-01, 8.53167852e-01,
#        1.37382380e+00, 2.21221629e+00, 3.56224789e+00, 5.73615251e+00,
#        9.23670857e+00, 1.48735211e+01, 2.39502662e+01, 3.85662042e+01,
#        6.21016942e+01, 1.00000000e+02]),
#              cv=KFold(n_splits=5, random_state=42, shuffle=True),
#              l1_ratio=[0.1, 0.5, 0.9, 1.0], max_iter=20000, n_jobs=-1)

# %%
pipe.fit(X_train, y_train)

model = pipe.named_steps["model"]

print("Mejor alpha:", model.alpha_)
print("Mejor l1_ratio:", model.l1_ratio_)


def mse(y_true, y_pred):
    return mean_squared_error(y_true, y_pred)


def rmse(y_true, y_pred):
    return np.sqrt(mse(y_true, y_pred))


train_pred = pipe.predict(X_train)
test_pred = pipe.predict(X_test)

print("MSE train:", mse(y_train, train_pred))
print("MSE test:", mse(y_test, test_pred))
print("RMSE train:", rmse(y_train, train_pred))
print("RMSE test:", rmse(y_test, test_pred))
print("R2 train:", r2_score(y_train, train_pred))
print("R2 test:", r2_score(y_test, test_pred))
# Out:
# Mejor alpha: 0.12689610031679222
# Mejor l1_ratio: 0.9
# MSE train: 82.50539716635204
# MSE test: 57.61373310836748
# RMSE train: 9.083248161662878
# RMSE test: 7.590371078436645
# R2 train: 0.5524795406928137
# R2 test: 0.6897857812641689

# %% [markdown]
# ## ¿Cómo funciona la selección de variables en Elastic Net?
#
# Elastic Net combina L1 (Lasso) y L2 (Ridge):
#
# - **L1** puede llevar coeficientes exactamente a cero → *selección de variables*.
# - **L2** encoge coeficientes pero rara vez los hace cero.
#
# En el código, consideramos seleccionadas las variables con `|coef| > 1e-6` y mostramos el top por magnitud. Es una forma práctica de ver qué entra en el modelo.

# %%
mse_path = model.mse_path_  # shape: (n_l1_ratio, n_alpha, n_folds)
mean_mse = mse_path.mean(axis=2)

l1_ratio_list = model.l1_ratio
if not isinstance(l1_ratio_list, (list, tuple, np.ndarray)):
    l1_ratio_list = [model.l1_ratio_]

plt.figure(figsize=(8, 5))
for i, l1 in enumerate(l1_ratio_list):
    plt.semilogx(model.alphas_, mean_mse[i], label=f"l1_ratio={l1}")

plt.axvline(model.alpha_, color="black", linestyle="--", label="mejor alpha")
plt.xlabel("alpha (log escala)")
plt.ylabel("MSE promedio CV")
plt.title("ElasticNetCV: Error de validación cruzada")
plt.legend()
plt.show()

# %%
pipe.named_steps #['model'].coef_
# model.coef_[-1]
# Out:
# {'preprocess': ColumnTransformer(transformers=[('num', StandardScaler(),
#                                   ['X1 transaction date', 'X2 house age',
#                                    'X3 distance to the nearest MRT station',
#                                    'X4 number of convenience stores',
#                                    'X5 latitude', 'X6 longitude']),
#                                  ('cat', OneHotEncoder(handle_unknown='ignore'),
#                                   [])]),
#  'model': ElasticNetCV(alphas=array([1.00000000e-04, 1.61026203e-04, 2.59294380e-04, 4.17531894e-04,
#         6.72335754e-04, 1.08263673e-03, 1.74332882e-03, 2.80721620e-03,
#         4.52035366e-03, 7.27895384e-03, 1.17210230e-02, 1.88739182e-02,
#         3.03919538e-02, 4.89390092e-02, 7.88046282e-02, 1.26896100e-01,
#         2.04335972e-01, 3.29034456e-01, 5.29831691e-01, 8.53167852e-01,
#         1.37382380e+00, 2.21221629e+00, 3.56224789e+00, 5.73615251e+00,
#         9.23670857e+00, 1.48735211e+01, 2.39502662e+01, 3.85662042e+01,
#         6.21016942e+01, 1.00000000e+02]),
#               cv=KFold(n_splits=5, random_state=42, shuffle=True),
#               l1_ratio=[0.1, 0.5, 0.9, 1.0], max_iter=20000, n_jobs=-1)}

# %%
feature_names = pipe.named_steps["preprocess"].get_feature_names_out()
coefs = model.coef_

coef_df = pd.DataFrame({"feature": feature_names, "coef": coefs})
coef_df["abs_coef"] = coef_df["coef"].abs()

selected = coef_df[coef_df["abs_coef"] > 1e-6].copy()
print("Variables seleccionadas (coef != 0):", selected.shape[0])

print("Top 20 por |coef|:")
display(selected.sort_values("abs_coef", ascending=False).head(20))

# (Opcional) Re-entrenar sobre variables seleccionadas
preprocessor = pipe.named_steps["preprocess"]
X_train_proc = preprocessor.transform(X_train)
X_test_proc = preprocessor.transform(X_test)

selector = SelectFromModel(model, threshold=1e-6, prefit=True)
X_train_sel = selector.transform(X_train_proc)
X_test_sel = selector.transform(X_test_proc)

final_model = ElasticNet(alpha=model.alpha_, l1_ratio=model.l1_ratio_, max_iter=20000)
final_model.fit(X_train_sel, y_train)

train_pred_sel = final_model.predict(X_train_sel)
test_pred_sel = final_model.predict(X_test_sel)

print("RMSE train (selección):", rmse(y_train, train_pred_sel))
print("RMSE test (selección):", rmse(y_test, test_pred_sel))
# Out:
# Variables seleccionadas (coef != 0): 6
# Top 20 por |coef|:
#                                        feature      coef  abs_coef
# 2  num__X3 distance to the nearest MRT station -5.136719  5.136719
# 3         num__X4 number of convenience stores  3.225320  3.225320
# 1                            num__X2 house age -2.920511  2.920511
# 4                             num__X5 latitude  2.891862  2.891862
# 0                     num__X1 transaction date  1.434563  1.434563
# 5                            num__X6 longitude  0.053670  0.053670
# RMSE train (selección): 9.125771134228174
# RMSE test (selección): 7.278412112004002

# %% [markdown]
# ## Interpretación rápida
#
# - Si el RMSE de test es mucho mayor que el de train, hay overfitting.
# - Al aumentar `alpha`, la penalización sube y los coeficientes se encogen (más sesgo, menos varianza).
# - `l1_ratio` cerca de 1 produce más ceros (selección de variables).

# %% [markdown]
# ## Polinomios + Elastic Net con selección y re-entrenamiento
#
# En este bloque **sí** usamos polinomios y luego seleccionamos variables con Elastic Net para re-entrenar un modelo más simple.

# %%
# Asegurar funciones de error disponibles

def mse(y_true, y_pred):
    return mean_squared_error(y_true, y_pred)


def rmse(y_true, y_pred):
    return np.sqrt(mse(y_true, y_pred))

# %%
# Desviación estándar de variables explicativas (X) y del target (Y)
print("Desv. est. de Y (train):", y_train.std())
print("Desv. est. de Y (test):", y_test.std())

if numeric_features:
    X_train_std = X_train[numeric_features].std().sort_values(ascending=False)
    print("Desv. est. de X (train), top 10:")
    display(X_train_std.head(10))
# Out:
# Desv. est. de Y (train): 13.735373081186841
# Desv. est. de Y (test): 13.030947588843244
# Desv. est. de X (train), top 10:
# X3 distance to the nearest MRT station    1217.929569
# X2 house age                                11.327281
# X4 number of convenience stores              2.953703
# X1 transaction date                          0.281570
# X6 longitude                                 0.014976
# X5 latitude                                  0.012484
# dtype: float64

# %%
# Polinomios en variables numéricas + Elastic Net
poly_preprocess = ColumnTransformer(
    transformers=[
        (
            "num",
            Pipeline(
                steps=[
                    ("poly", PolynomialFeatures(degree=2, include_bias=False)),
                    ("scaler", StandardScaler()),
                ]
            ),
            numeric_features,
        ),
        ("cat", OneHotEncoder(handle_unknown="ignore"), categorical_features),
    ],
    remainder="drop",
)

poly_model = ElasticNetCV(
    l1_ratio=l1_ratios,
    alphas=alphas,
    cv=cv,
    max_iter=20000,
    n_jobs=-1,
)

poly_pipe = Pipeline(
    steps=[
        ("preprocess", poly_preprocess),
        ("model", poly_model),
    ]
)

poly_pipe.fit(X_train, y_train)
poly_test_pred = poly_pipe.predict(X_test)
# Out:
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.334e+00, tolerance: 4.251e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.578e+02, tolerance: 5.094e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.590e+01, tolerance: 5.206e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.022e+02, tolerance: 5.094e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.560e+02, tolerance: 5.206e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.706e+01, tolerance: 5.022e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.640e+02, tolerance: 4.251e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.282e+02, tolerance: 5.306e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.342e+02, tolerance: 4.251e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.125e+02, tolerance: 5.206e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.474e+01, tolerance: 5.094e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.123e+03, tolerance: 5.094e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.036e+03, tolerance: 5.206e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.233e+02, tolerance: 4.251e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.373e+02, tolerance: 5.022e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.469e+02, tolerance: 5.206e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.661e+02, tolerance: 5.094e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.835e+02, tolerance: 4.251e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.092e+03, tolerance: 5.306e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.870e+03, tolerance: 5.094e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.864e+03, tolerance: 5.206e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.706e+02, tolerance: 4.251e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.412e+03, tolerance: 5.206e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.459e+03, tolerance: 5.022e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.897e+03, tolerance: 5.306e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.903e+03, tolerance: 4.251e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.233e+03, tolerance: 5.094e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.311e+03, tolerance: 5.022e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.059e+03, tolerance: 5.206e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.534e+03, tolerance: 5.094e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.428e+03, tolerance: 5.306e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.464e+03, tolerance: 4.251e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.151e+01, tolerance: 5.094e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.245e+01, tolerance: 5.022e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.005e+01, tolerance: 5.306e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.508e+01, tolerance: 5.094e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.186e+01, tolerance: 5.094e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.382e+00, tolerance: 4.251e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.477e+01, tolerance: 5.022e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.294e+01, tolerance: 5.094e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.750e+02, tolerance: 5.306e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.788e+00, tolerance: 5.206e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.292e+00, tolerance: 5.022e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.520e+02, tolerance: 5.094e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.059e+01, tolerance: 4.251e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.240e+03, tolerance: 5.094e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.555e+02, tolerance: 5.306e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.409e+01, tolerance: 5.022e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.097e+01, tolerance: 5.206e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.654e+02, tolerance: 5.022e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.306e+02, tolerance: 5.094e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.170e+01, tolerance: 4.251e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.034e+03, tolerance: 5.094e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.901e+01, tolerance: 5.022e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.882e+03, tolerance: 5.306e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.259e+02, tolerance: 5.206e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.285e+03, tolerance: 5.094e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.076e+03, tolerance: 5.022e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.125e+03, tolerance: 5.094e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.837e+02, tolerance: 5.022e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.299e+02, tolerance: 4.251e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.418e+03, tolerance: 5.094e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.924e+02, tolerance: 5.206e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.829e+02, tolerance: 5.022e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.131e+03, tolerance: 4.251e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.664e+01, tolerance: 5.306e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.196e+02, tolerance: 4.251e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.921e+02, tolerance: 5.206e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.035e+01, tolerance: 5.306e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.508e+02, tolerance: 5.206e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.937e+02, tolerance: 5.022e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.827e+00, tolerance: 5.022e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.059e+01, tolerance: 4.251e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.779e+01, tolerance: 5.306e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.240e+03, tolerance: 5.206e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.068e+03, tolerance: 5.206e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.900e+01, tolerance: 5.306e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.881e+01, tolerance: 5.022e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.875e+01, tolerance: 5.306e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.272e+03, tolerance: 5.206e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.354e+03, tolerance: 4.251e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.801e+01, tolerance: 5.306e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.016e+03, tolerance: 5.022e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.043e+03, tolerance: 4.251e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.873e+03, tolerance: 5.306e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.156e+02, tolerance: 5.306e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.450e+03, tolerance: 5.306e+00
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.906e+03, tolerance: 5.306e+00
#   model = cd_fast.enet_coordinate_descent_gram(

# %%
print("MSE test (polinomios):", mse(y_test, poly_test_pred))
print("RMSE test (polinomios):", rmse(y_test, poly_test_pred))

# Selección de variables con Elastic Net y re-entrenamiento
poly_feature_names = poly_pipe.named_steps["preprocess"].get_feature_names_out()
poly_coefs = poly_model.coef_

poly_coef_df = pd.DataFrame({"feature": poly_feature_names, "coef": poly_coefs})
poly_coef_df["abs_coef"] = poly_coef_df["coef"].abs()
selected_poly = poly_coef_df[poly_coef_df["abs_coef"] > 1e-6]

print("="*80)
print("Variables seleccionadas (polinomios, coef != 0):", selected_poly.shape[0], '\n\n')
print("Top 20 por |coef| (polinomios):")
display(
    selected_poly.sort_values("abs_coef", ascending=False).head(20)
    )
print("="*80)

poly_preprocessor = poly_pipe.named_steps["preprocess"]
X_train_poly = poly_preprocessor.transform(X_train)
X_test_poly = poly_preprocessor.transform(X_test)

poly_selector = SelectFromModel(poly_model, threshold=1e-6, prefit=True)
X_train_poly_sel = poly_selector.transform(X_train_poly)
X_test_poly_sel = poly_selector.transform(X_test_poly)

poly_final = ElasticNet(alpha=poly_model.alpha_, l1_ratio=poly_model.l1_ratio_, max_iter=20000)
poly_final.fit(X_train_poly_sel, y_train)

poly_train_pred_sel = poly_final.predict(X_train_poly_sel)
poly_test_pred_sel = poly_final.predict(X_test_poly_sel)

print("MSE test (polinomios + selección):", mse(y_test, poly_test_pred_sel))
print("RMSE test (polinomios + selección):", rmse(y_test, poly_test_pred_sel))
# Out:
# MSE test (polinomios): 38.86345378489118
# RMSE test (polinomios): 6.234055965813202
# ================================================================================
# Variables seleccionadas (polinomios, coef != 0): 26
#
#
# Top 20 por |coef| (polinomios):
#                                               feature      coef  abs_coef
# 12                                num__X2 house age^2  6.417726  6.417726
# 17      num__X3 distance to the nearest MRT station^2  3.857476  3.857476
# 18  num__X3 distance to the nearest MRT station X4... -3.095483  3.095483
# 15                      num__X2 house age X5 latitude -2.553435  2.553435
# 16                     num__X2 house age X6 longitude -2.550921  2.550921
# 1                                   num__X2 house age -2.549356  2.549356
# 7               num__X1 transaction date X2 house age -2.547764  2.547764
# 19  num__X3 distance to the nearest MRT station X5... -2.289856  2.289856
# 8   num__X1 transaction date X3 distance to the ne... -2.260617  2.260617
# 2         num__X3 distance to the nearest MRT station -2.260120  2.260120
# 20  num__X3 distance to the nearest MRT station X6... -2.259560  2.259560
# 21             num__X4 number of convenience stores^2 -1.601455  1.601455
# 13  num__X2 house age X3 distance to the nearest M...  1.314960  1.314960
# 23  num__X4 number of convenience stores X6 longitude  1.244968  1.244968
# 3                num__X4 number of convenience stores  1.244412  1.244412
# 9   num__X1 transaction date X4 number of convenie...  1.242819  1.242819
# 22   num__X4 number of convenience stores X5 latitude  1.238319  1.238319
# 10               num__X1 transaction date X5 latitude  1.128235  1.128235
# 4                                    num__X5 latitude  0.952422  0.952422
# 24                                 num__X5 latitude^2  0.951052  0.951052
# ================================================================================
# MSE test (polinomios + selección): 38.86346304980767
# RMSE test (polinomios + selección): 6.2340567089021315
